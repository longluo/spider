# %% [markdown]
# # Python 微博热搜爬虫与数据展示
#
# ------------
#
# ## 介绍
#
# 使用 Python 调用微博移动端 api 爬虫当前热搜榜&热评，并将数据结果保存为 .csv。
#
# * 本项目无框架使用
# * 本项目部分代码来自网络
# * 本项目使用以下关键的包或库：
#     * requests，json，处理请求
#     * re，正则内容匹配与过滤
#     * pandas，数据处理
#     * csv，存储数据结果

# %%
import requests
import pandas as pd
from time import sleep
import numpy as np
from lxml import etree
import re
import os
import csv

class Weibo(object):
    def __init__(self):
        """初始化爬虫信息"""
        self.weiboHotUrl = 'https://s.weibo.com/top/summary?cate=realtimehot'
        user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36"
        cookie = "SINAGLOBAL=6788372453151.379.1593919176064; _ga=GA1.2.1601691111.1602690890; UOR=,,www.baidu.com; SUBP=0033WrSXqPxfM725Ws9jqgMF55529P9D9WFosG2CxEf1L.SYPEcqN8-S5JpX5KMhUgL.FoMfSoBf1KzcShq2dJLoIp7LxKML1KBLBKnLxKqL1hnLBoMNSKqXSK.ESoBc; SSOLoginState=1653261113; _s_tentry=weibo.com; Apache=5632904354559.916.1653261124393; ULV=1653261124397:835:29:2:5632904354559.916.1653261124393:1653185715238; SCF=Ajsb1zoR2IQmauat98BKUW-CLBtWJExctPE4XBmqrc7nWVgtDoqBZVkcE-NAB9de2_dsF7sNX88GQGt9FHG5xas.; SUB=_2A25Pj0vODeRhGeFL7VYU-SzKzzqIHXVs_ToGrDV8PUNbmtAfLW6jkW9NfcDmWmhDk0PGX0xl5Jt27ZGzSG9UmKZG"
        self.headers = {"User_Agent": user_agent, "Cookie": cookie}
        self.all_df = pd.DataFrame(columns=['排行', '热度', '标题', '评论时间', '用户名称', '转发次数', '评论次数', '点赞次数', '评论内容'])
        
    def start(self):
        """运行爬虫"""
        print(self.all_df)
        self.get_hot_list()
        self.save_to_csv()
         
    def get_hot_list(self):
        '''
        微博热搜页面采集，获取详情页链接后，跳转进入详情页采集
        :param url: 微博热搜页链接
        :return: None
        '''
        page_text = requests.get(url=self.weiboHotUrl, headers=self.headers).text
        tree = etree.HTML(page_text)
        tr_list = tree.xpath('//*[@id="pl_top_realtimehot"]/table/tbody/tr')
        for tr in tr_list:
            parse_url = tr.xpath('./td[2]/a/@href')[0]
            detail_url = 'https://s.weibo.com' + parse_url
            title = tr.xpath('./td[2]/a/text()')[0]
            try:
                rank = tr.xpath('./td[1]/text()')[0]
                hot = tr.xpath('./td[2]/span/text()')[0]
            except:
                rank = '置顶'
                hot = '置顶'
            self.get_detail_page(detail_url, title, rank, hot)
        
    def get_detail_page(self, detail_url, title, rank, hot):
        '''
        根据详情页链接，解析所需页面数据，并保存到全局变量 all_df
        :param detail_url: 详情页链接
        :param title: 标题
        :param rank: 排名
        :param hot: 热度
        :return: None
        '''
        try:
            page_text = requests.get(url=detail_url, headers=self.headers).text
        except:
            return None
        tree = etree.HTML(page_text)
        result_df = pd.DataFrame(columns=np.array(self.all_df.columns))

        # 爬取3条热门评论信息
        for i in range(1, 4):
            try:
                comment_time = tree.xpath(f'//*[@id="pl_feedlist_index"]/div[4]/div[{i}]/div[2]/div[1]/div[2]/p[1]/a/text()')[0]
                comment_time = re.sub('\s','',comment_time)
                user_name = tree.xpath(f'//*[@id="pl_feedlist_index"]/div[4]/div[{i}]/div[2]/div[1]/div[2]/p[2]/@nick-name')[0]
                forward_count = tree.xpath(f'//*[@id="pl_feedlist_index"]/div[4]/div[{i}]/div[2]/div[2]/ul/li[1]/a/text()')[1]
                forward_count = forward_count.strip()
                comment_count = tree.xpath(f'//*[@id="pl_feedlist_index"]/div[4]/div[{i}]/div[2]/div[2]/ul/li[2]/a/text()')[0]
                comment_count = comment_count.strip()
                like_count = tree.xpath(f'//*[@id="pl_feedlist_index"]/div[4]/div[{i}]/div[2]/div[2]/ul/li[3]/a/button/span[2]/text()')[0]
                comment = tree.xpath(f'//*[@id="pl_feedlist_index"]/div[4]/div[{i}]/div[2]/div[1]/div[2]/p[2]//text()')
                comment = ' '.join(comment).strip()
                result_df.loc[len(result_df), :] = [rank, hot, title, comment_time, user_name, forward_count, comment_count, like_count, comment]
            except Exception as e:
                print(e)
                continue
        print(detail_url, title)
        self.all_df = self.all_df.append(result_df, ignore_index=True)        
        
    def save_to_csv(self):
        self.all_df.to_csv(r"weibo.csv", mode = 'a', encoding="utf-8-sig", index=False)
    
def main():
    wb = Weibo()
    wb.start() # 爬取微博信息
        
        
if __name__ == "__main__":
    main()
# Out:
# Empty DataFrame
# Columns: [排行, 热度, 标题, 评论时间, 用户名称, 转发次数, 评论次数, 点赞次数, 评论内容]
# Index: []
# https://s.weibo.com/weibo?q=%23%E8%AE%A9%E4%B8%AD%E5%9B%BD%E6%96%87%E8%89%BA%E7%9A%84%E5%A4%A9%E7%A9%BA%E6%9B%B4%E5%8A%A0%E7%BE%A4%E6%98%9F%E7%81%BF%E7%83%82%23&Refer=new_time 让中国文艺的天空更加群星灿烂
# https://s.weibo.com/weibo?q=%23%E4%B8%8A%E6%B5%B7%E8%A5%BF%E7%93%9C%E6%BB%9E%E9%94%80%E7%93%9C%E5%86%9C%E6%B1%82%E5%8A%A9%23&Refer=top 上海西瓜滞销瓜农求助
# https://s.weibo.com/weibo?q=%23%E8%BF%99%E4%BA%9B%E4%B8%9C%E8%A5%BF%E7%9C%9F%E7%9A%84%E4%BC%9A%E8%87%B4%E7%99%8C%23&Refer=top 这些东西真的会致癌
# https://s.weibo.com/weibo?q=%23%E5%85%A8%E9%BA%BB%E6%89%8B%E6%9C%AF%E9%86%92%E5%90%8E%E6%9C%89%E5%A4%9A%E7%A4%BE%E6%AD%BB%23&Refer=top 全麻手术醒后有多社死
# list index out of range
# list index out of range
# list index out of range
# https://s.weibo.com/weibo?q=%E7%8E%8B%E5%BF%83%E5%87%8C%20%E6%96%AD%E5%B1%82&Refer=top 王心凌 断层
# https://s.weibo.com/weibo?q=%23%E5%85%AD%E5%85%AC%E4%B8%BB%E6%92%AD%E7%8F%8D%E7%8F%A0%E6%B8%AF%23&Refer=top 六公主播珍珠港
# https://s.weibo.com/weibo?q=%23%E6%B2%88%E5%BA%86%E8%BD%A6%E7%A5%B8%E5%8E%BB%E4%B8%96%23&Refer=top 沈庆车祸去世
# https://s.weibo.com/weibo?q=%23%E6%8B%9C%E7%99%BB%E7%A7%B0%E6%AD%A3%E5%9C%A8%E8%80%83%E8%99%91%E5%8F%96%E6%B6%88%E5%AF%B9%E4%B8%AD%E5%9B%BD%E7%9A%84%E5%85%B3%E7%A8%8E%E5%A3%81%E5%9E%92%23&Refer=top 拜登称正在考虑取消对中国的关税壁垒
# https://s.weibo.com/weibo?q=%23%E5%88%86%E4%BA%AB%E6%AC%B2%E5%B0%B1%E6%98%AF%E6%B5%AA%E6%BC%AB%E5%92%8C%E7%83%AD%E6%83%85%E6%9C%AC%E8%BA%AB%23&Refer=top 分享欲就是浪漫和热情本身
# https://s.weibo.com/weibo?q=%23%E6%8A%A5%E8%80%83%E5%8D%8F%E8%AD%A6%E6%B8%85%E5%8D%8E%E5%8D%9A%E5%A3%AB%E5%AD%A6%E5%8E%86%E4%B8%BA%E8%AF%AF%E5%A1%AB%23&Refer=top 报考协警清华博士学历为误填
# https://s.weibo.com/weibo?q=%23%E5%A5%B3%E7%94%9F%E4%BC%AA%E9%80%A0%E5%BD%95%E5%8F%96%E9%80%9A%E7%9F%A5%E4%B9%A6%E8%A2%AB%E7%88%B8%E7%88%B8%E6%89%93%E8%80%B3%E5%85%89%23&Refer=top 女生伪造录取通知书被爸爸打耳光
# https://s.weibo.com/weibo?q=%23%E5%8C%97%E4%BA%AC%E6%B5%B7%E6%B7%80%E8%BF%85%E9%80%9F%E5%BC%80%E5%B1%95%E9%87%8D%E7%82%B9%E5%8C%BA%E5%9F%9F%E9%A3%8E%E9%99%A9%E4%BA%BA%E5%91%98%E8%BD%AC%E8%BF%90%23&Refer=top 北京海淀迅速开展重点区域风险人员转运
# https://s.weibo.com/weibo?q=%23%E6%9D%A8%E8%B6%85%E8%B6%8A%E6%BC%94%E7%9A%84%E6%B8%A9%E6%9F%94%23&Refer=top 杨超越演的温柔
# https://s.weibo.com/weibo?q=%23BLACKPINK%E6%BB%9A%E7%9F%B3%E6%9D%82%E5%BF%97%E5%B0%81%E9%9D%A2%23&Refer=top BLACKPINK滚石杂志封面
# https://s.weibo.com/weibo?q=%23%E6%8E%A5%E8%A7%A6%E7%8C%B4%E7%97%98%E7%97%85%E6%AF%92%E5%90%8E%E6%8E%A5%E7%A7%8D%E5%A4%A9%E8%8A%B1%E7%96%AB%E8%8B%97%E4%BB%8D%E6%9C%89%E6%95%88%23&Refer=top 接触猴痘病毒后接种天花疫苗仍有效
# https://s.weibo.com/weibo?q=%23RNG%E6%99%8B%E7%BA%A7%E5%8D%8A%E5%86%B3%E8%B5%9B%23&Refer=top RNG晋级半决赛
# https://s.weibo.com/weibo?q=%23%E5%93%AA%E4%BA%9B%E5%B0%8F%E8%AF%B4%E9%A1%B6%E7%BA%A7%E8%80%90%E7%9C%8B%E7%BB%8F%E4%B9%85%E4%B8%8D%E8%A1%B0%23&Refer=top 哪些小说顶级耐看经久不衰
# https://s.weibo.com/weibo?q=%23%E9%9D%92%E7%BE%8A%E5%8C%BA%E5%8F%91%E7%8E%B01%E4%BE%8B%E6%96%B0%E5%86%A0%E8%82%BA%E7%82%8E%E6%9C%AC%E5%9C%9F%E7%97%85%E4%BE%8B%23&Refer=top 青羊区发现1例新冠肺炎本土病例
# https://s.weibo.com/weibo?q=%23%E7%94%B7%E5%AD%90%E5%AB%8C%E5%A6%BB%E5%AD%90%E5%A4%AA%E5%87%B6%E4%BA%B2%E8%87%AA%E8%BE%85%E5%AF%BC%E6%B0%94%E5%BE%97%E6%92%9E%E8%A1%A3%E6%9F%9C%23&Refer=top 男子嫌妻子太凶亲自辅导气得撞衣柜
# https://s.weibo.com/weibo?q=%23%E4%BD%A0%E4%BB%A5%E4%B8%BA%E7%9A%84%E4%B8%A2%E4%BA%BA%E5%8F%AF%E8%83%BD%E5%8F%AA%E6%98%AF%E5%86%85%E5%BF%83%E6%88%8F%23&Refer=top 你以为的丢人可能只是内心戏
# https://s.weibo.com/weibo?q=%23%E6%9B%BE%E8%88%9C%E6%99%9E%E6%96%B0%E5%89%A7%E6%AD%A6%E4%BE%A0%E6%84%9F%E8%B7%A8%E5%BA%A6%E5%A5%BD%E5%A4%A7%23&Refer=top 曾舜晞新剧武侠感跨度好大
# https://s.weibo.com/weibo?q=%23Gala%E7%9A%84%E5%8D%A1%E8%8E%8E%23&Refer=top Gala的卡莎
# https://s.weibo.com/weibo?q=%23%E8%B7%9D2022%E9%AB%98%E8%80%83%E8%BF%98%E6%9C%8915%E5%A4%A9%23&Refer=top 距2022高考还有15天
# https://s.weibo.com/weibo?q=%23%E6%8B%9C%E7%99%BB%E5%9C%A8%E4%B8%9C%E4%BA%AC%E6%AD%A3%E5%BC%8F%E5%AE%A3%E5%B8%83%E5%90%AF%E5%8A%A8%E5%8D%B0%E5%A4%AA%E7%BB%8F%E6%B5%8E%E6%A1%86%E6%9E%B6%23&Refer=top 拜登在东京正式宣布启动印太经济框架
# https://s.weibo.com/weibo?q=%23%E6%B8%85%E5%8D%8E%E5%A4%A7%E5%AD%A6%E7%A7%B0%E7%BD%91%E4%BC%A0%E6%8A%A5%E8%80%83%E5%8D%8F%E8%AD%A6%E5%8D%9A%E5%A3%AB%E4%B8%8D%E5%9C%A8%E8%AF%A5%E6%A0%A1%E5%AD%A6%E7%B1%8D%E5%BA%93%23&Refer=top 清华大学称网传报考协警博士不在该校学籍库
# https://s.weibo.com/weibo?q=%23%E5%AF%8C%E4%BA%8C%E4%BB%A3%E7%9B%97%E7%AA%83%E8%87%AA%E5%AE%B6%E5%B7%A5%E5%8E%8256%E6%AC%A1%E8%A2%AB%E7%88%B6%E4%BA%B2%E9%80%81%E4%B8%8A%E6%B3%95%E5%BA%AD%23&Refer=top 富二代盗窃自家工厂56次被父亲送上法庭
# list index out of range
# list index out of range
# list index out of range
# https://s.weibo.com/weibo?q=%E6%9E%97%E6%9B%B4%E6%96%B0%20%E4%B8%8E%E5%87%A4%E8%A1%8C&Refer=top 林更新 与凤行
# list index out of range
# list index out of range
# list index out of range
# https://s.weibo.com/weibo?q=%E5%8D%8E%E4%B8%BA%E5%8F%91%E5%B8%83%E4%BC%9A&Refer=top 华为发布会
# https://s.weibo.com/weibo?q=%23%E5%8F%AF%E8%BE%BE%E9%B8%AD%E5%95%86%E6%A0%87%E8%A2%AB%E4%BB%BB%E5%A4%A9%E5%A0%82%E6%B3%A8%E5%86%8C%23&Refer=top 可达鸭商标被任天堂注册
# https://s.weibo.com/weibo?q=%23%E7%94%B7%E5%AD%90%E6%89%BE%E5%96%9C%E6%AC%A2%E7%9A%84%E4%BA%BA%E8%A6%81%E8%87%AA%E6%8B%8D%E5%8D%B4%E6%94%B6%E5%88%B0X%E5%85%89%23&Refer=top 男子找喜欢的人要自拍却收到X光
# https://s.weibo.com/weibo?q=%23%E4%B8%AD%E6%96%B9%E5%9B%9E%E5%BA%94%E6%8B%9C%E7%99%BB%E5%A3%B0%E7%A7%B0%E7%BE%8E%E5%B0%86%E5%86%9B%E4%BA%8B%E5%B9%B2%E9%A2%84%E5%8F%B0%E6%B9%BE%E9%97%AE%E9%A2%98%23&Refer=top 中方回应拜登声称美将军事干预台湾问题
# https://s.weibo.com/weibo?q=%23%E5%90%B4%E7%A3%8A%E8%B9%B2%E4%B8%8B%E7%9A%84%E7%9E%AC%E9%97%B4%E4%BB%96%E4%BB%AC%E4%B9%8B%E9%97%B4%E7%BC%A9%E7%9F%AD%E4%BA%8678%E5%B9%B4%23&Refer=top 吴磊蹲下的瞬间他们之间缩短了78年
# https://s.weibo.com/weibo?q=%23%E5%BD%93%E4%BB%A3%E5%A5%B3%E7%94%9F%E4%B9%B0%E8%A3%99%E5%AD%90%E6%9C%89%E5%A4%9A%E9%9A%BE%23&Refer=top 当代女生买裙子有多难
# list index out of range
# list index out of range
# https://s.weibo.com/weibo?q=%23MSI%E7%A7%AF%E5%88%86%23&Refer=top MSI积分
# https://s.weibo.com/weibo?q=%23%E4%B8%94%E8%AF%95%E5%A4%A9%E4%B8%8B%E8%B1%86%E7%93%A3%E8%AF%84%E5%88%865.8%23&Refer=top 且试天下豆瓣评分5.8
# https://s.weibo.com/weibo?q=%23%E5%8F%AF%E8%BE%BE%E9%B8%AD%E4%B8%BA%E4%BB%80%E4%B9%88%E8%BF%99%E4%B9%88%E7%81%AB%23&Refer=top 可达鸭为什么这么火
# https://s.weibo.com/weibo?q=%23%E5%8C%97%E4%BA%AC%E4%B8%80%E7%A4%BE%E5%8C%BA19%E4%BE%8B%E9%98%B3%E6%80%A7%E4%B8%8E%E5%A4%9A%E5%AE%B6%E5%BA%AD%E9%97%B4%E8%81%9A%E4%BC%9A%E6%9C%89%E5%85%B3%23&Refer=top 北京一社区19例阳性与多家庭间聚会有关
# list index out of range
# list index out of range
# list index out of range
# https://s.weibo.com/weibo?q=%E6%AC%A2%E9%A2%9C&Refer=top 欢颜
# https://s.weibo.com/weibo?q=%23%E8%A7%92%E8%89%B2%E7%9E%AC%E9%97%B4%E9%80%86%E8%BD%AC%E7%A7%98%E8%AF%80%23&Refer=top 角色瞬间逆转秘诀
# https://s.weibo.com/weibo?q=%23%E5%BC%A0%E6%96%87%E5%AE%8F%E7%A7%B0%E5%8F%AF%E8%83%BD%E6%96%B0%E5%86%A0%E7%96%AB%E6%83%85%E7%9F%AD%E6%9C%9F%E5%86%85%E4%B8%8D%E4%BC%9A%E7%BB%93%E6%9D%9F%23&Refer=top 张文宏称可能新冠疫情短期内不会结束
# https://s.weibo.com/weibo?q=%23RNG%E5%AF%B9%E6%88%98EG%23&Refer=top RNG对战EG
# https://s.weibo.com/weibo?q=%23%E9%AB%98%E5%8D%BF%E5%B0%98%E5%8F%A4%E8%A3%85%E7%BF%BB%E5%94%B1%E5%89%91%E4%BC%A4%23&Refer=top 高卿尘古装翻唱剑伤
# https://s.weibo.com/weibo?q=%23%E5%A5%A5%E5%AF%86%E5%85%8B%E6%88%8E%E8%AF%B1%E5%8F%91%E7%9A%84%E7%82%8E%E7%97%87%E5%8F%8D%E5%BA%94%E4%B8%8E%E6%B5%81%E6%84%9F%E6%98%8E%E6%98%BE%E4%B8%8D%E5%90%8C%23&Refer=top 奥密克戎诱发的炎症反应与流感明显不同
# https://s.weibo.com/weibo?q=%23RNG%E6%88%98%E8%83%9CEG%23&Refer=top RNG战胜EG
# https://s.weibo.com/weibo?q=%23%E7%94%B7%E5%AD%90%E9%85%92%E9%A9%BE%E8%A2%AB%E6%9F%A5%E7%8B%82%E5%96%9D%E6%B0%B4%E8%A6%81%E6%B1%82%E9%87%8D%E6%B5%8B%23&Refer=top 男子酒驾被查狂喝水要求重测
# list index out of range
# list index out of range
# list index out of range
# https://s.weibo.com/weibo?q=%E4%B8%8E%E5%87%A4%E8%A1%8C&Refer=top 与凤行
# list index out of range
# list index out of range
# list index out of range
# https://s.weibo.com/weibo?q=k4%E6%9C%8D%E5%8A%A1%E5%99%A8&Refer=top k4服务器
# https://s.weibo.com/weibo?q=%23%E5%9B%BD%E5%86%85%E6%B2%B9%E4%BB%B7%E6%88%96%E9%9D%A2%E4%B8%B4%E5%B9%B4%E5%86%85%E7%AC%AC%E4%B9%9D%E6%B6%A8%23&Refer=top 国内油价或面临年内第九涨
# https://s.weibo.com/weibo?q=%23%E4%B8%8A%E6%B5%B7%E7%90%86%E5%B7%A5%E5%A4%A7%E5%AD%A6%E8%BE%9F%E8%B0%A3%E5%A4%96%E7%9C%81%E9%9A%94%E7%A6%BB%E5%AD%A6%E7%94%9F%E8%BF%94%E6%B2%AA%23&Refer=top 上海理工大学辟谣外省隔离学生返沪
